# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="Rossum"></p>
#
#
# ____

# %%
import pandas as pd
import numpy as np

# %%
ecom = pd.read_csv('data.csv',encoding= 'unicode_escape')

# %% [markdown]
# **Check the head of the DataFrame.**

# %%
ecom.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ** How many rows and columns are there? **

# %%
ecom.shape
# Out:
# (541909, 8)

# %%
ecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %% [markdown]
# ** Show the statistical measurements of ecom dataset **

# %%
ecom.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %% [markdown]
# ** What is the average Purchase Price? **

# %%
ecom.UnitPrice.mean()
# Out:
# 4.611113626083471

# %% [markdown]
# ** What were the highest and lowest purchase prices? **

# %%
ecom.UnitPrice.max()
# Out:
# 38970.0

# %%
ecom.UnitPrice.min()
# Out:
# -11062.06

# %% [markdown]
# ** List the country names and number of records belongs to each country **

# %%
ecom.Country.value_counts()
# Out:
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# European Community          61
# RSA                         58
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              30
# Bahrain                     19
# Saudi Arabia                10
# Name: Country, dtype: int64

# %% [markdown]
# ** How many records are as Country United Kingdom? **

# %%
ecom[ecom["Country"] == "United Kingdom"].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 495478 entries, 0 to 541893
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    495478 non-null  object
#  1   StockCode    495478 non-null  object
#  2   Description  494024 non-null  object
#  3   Quantity     495478 non-null  int64
#  4   InvoiceDate  495478 non-null  object
#  5   UnitPrice    495478 non-null  float64
#  6   CustomerID   361878 non-null  float64
#  7   Country      495478 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 34.0+ MB

# %%
ecom[ecom["Country"] == "United Kingdom"].count()
# Out:
# InvoiceNo      495478
# StockCode      495478
# Description    494024
# Quantity       495478
# InvoiceDate    495478
# UnitPrice      495478
# CustomerID     361878
# Country        495478
# dtype: int64

# %% [markdown]
# ** Create a column named Total which shows the total amount of spending using UnitPrice and Quantity ? **

# %%
ecom["Total"] = ecom["UnitPrice"] * ecom["Quantity"]
ecom["Total"]
# Out:
# 0         15.30
# 1         20.34
# 2         22.00
# 3         20.34
# 4         20.34
#           ...
# 541904    10.20
# 541905    12.60
# 541906    16.60
# 541907    16.60
# 541908    14.85
# Name: Total, Length: 541909, dtype: float64

# %% [markdown]
# ** Show total spending amount according to the Countries **

# %%
ecom.groupby("Country")["Total"].sum()
# Out:
# Country
# Australia                137077.270
# Austria                   10154.320
# Bahrain                     548.400
# Belgium                   40910.960
# Brazil                     1143.600
# Canada                     3666.380
# Channel Islands           20086.290
# Cyprus                    12946.290
# Czech Republic              707.720
# Denmark                   18768.140
# EIRE                     263276.820
# European Community         1291.750
# Finland                   22326.740
# France                   197403.900
# Germany                  221698.210
# Greece                     4710.520
# Hong Kong                 10117.040
# Iceland                    4310.000
# Israel                     7907.820
# Italy                     16890.510
# Japan                     35340.620
# Lebanon                    1693.880
# Lithuania                  1661.060
# Malta                      2505.470
# Netherlands              284661.540
# Norway                    35163.460
# Poland                     7213.140
# Portugal                  29367.020
# RSA                        1002.310
# Saudi Arabia                131.170
# Singapore                  9120.390
# Spain                     54774.580
# Sweden                    36595.910
# Switzerland               56385.350
# USA                        1730.920
# United Arab Emirates       1902.280
# United Kingdom          8187806.364
# Unspecified                4749.790
# Name: Total, dtype: float64

# %% [markdown]
# ** Which Country spent the least? **

# %%
ecom.groupby("Country")["Total"].sum().idxmin()
# Out:
# 'Saudi Arabia'

# %%
ecom.groupby("Country")["Total"].sum().min()
# Out:
# 131.17

# %% [markdown]
# ** Calculate average of spending according to country with apply function? **

# %%
ecom.groupby("Country")["Total"].apply(np.mean)
# Out:
# Country
# Australia               108.877895
# Austria                  25.322494
# Bahrain                  28.863158
# Belgium                  19.773301
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          26.499063
# Cyprus                   20.813971
# Czech Republic           23.590667
# Denmark                  48.247147
# EIRE                     32.122599
# European Community       21.176230
# Finland                  32.124806
# France                   23.069288
# Germany                  23.348943
# Greece                   32.263836
# Hong Kong                35.128611
# Iceland                  23.681319
# Israel                   26.625657
# Italy                    21.034259
# Japan                    98.716816
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    19.728110
# Netherlands             120.059696
# Norway                   32.378877
# Poland                   21.152903
# Portugal                 19.333127
# RSA                      17.281207
# Saudi Arabia             13.117000
# Singapore                39.827031
# Spain                    21.624390
# Sweden                   79.211926
# Switzerland              28.164510
# USA                       5.948179
# United Arab Emirates     27.974706
# United Kingdom           16.525065
# Unspecified              10.649753
# Name: Total, dtype: float64

# %% [markdown]
# ** Calculate average,min,max of spending according to country with agg function? **

# %%
ecom.groupby("Country")["Total"].agg([np.mean, np.min, np.max, np.median])
# Out:
#                             mean       amin       amax  median
# Country
# Australia             108.877895    -425.00    1718.40   51.84
# Austria                25.322494     -21.25     360.00   17.00
# Bahrain                28.863158    -205.74     205.74   25.50
# Belgium                19.773301     -19.95     165.00   16.60
# Brazil                 35.737500      15.00     175.20   19.65
# Canada                 24.280662       2.50     550.94   16.50
# Channel Islands        26.499063    -293.00     408.00   17.70
# Cyprus                 20.813971    -320.69     320.69   16.20
# Czech Republic         23.590667     -35.76      70.80   25.30
# Denmark                48.247147     -59.80     428.40   23.40
# EIRE                   32.122599   -1917.00    2365.20   17.34
# European Community     21.176230      -8.50      60.00   17.70
# Finland                32.124806     -80.00     551.20   17.85
# France                 23.069288   -8322.12    4161.06   16.50
# Germany                23.348943    -599.50     876.00   16.60
# Greece                 32.263836     -50.00     175.20   16.60
# Hong Kong              35.128611   -2653.95    2653.95   23.40
# Iceland                23.681319       5.04     249.60   17.00
# Israel                 26.625657    -136.00     350.40   17.85
# Italy                  21.034259     -89.55     300.00   17.40
# Japan                  98.716816   -1591.20    3794.40   61.20
# Lebanon                37.641778      10.20     153.00   31.60
# Lithuania              47.458857      13.20     122.40   45.00
# Malta                  19.728110    -130.00     455.00   17.00
# Netherlands           120.059696    -266.40    4992.00   91.80
# Norway                 32.378877    -376.50     700.00   19.80
# Poland                 21.152903     -39.80     120.00   17.40
# Portugal               19.333127   -1241.98    1241.98   15.80
# RSA                    17.281207       0.00      38.25   16.50
# Saudi Arabia           13.117000     -14.75      19.80   17.70
# Singapore              39.827031   -3949.32    3949.32   34.80
# Spain                  21.624390   -1715.85    1350.00   15.00
# Sweden                 79.211926   -1188.00    1188.00   30.00
# Switzerland            28.164510    -179.00     360.00   17.40
# USA                     5.948179     -74.88      81.36   10.50
# United Arab Emirates   27.974706       3.48     153.00   20.40
# United Kingdom         16.525065 -168469.60  168469.60    8.29
# Unspecified            10.649753       0.19      69.36    8.80

# %% [markdown]
# ** What is the max Total spending in whole dataset and show the records of that spending ?**

# %%
ecom[ecom["Total"] == ecom["Total"].max()]
# Out:
#        InvoiceNo StockCode                  Description  Quantity  \
# 540421    581483     23843  PAPER CRAFT , LITTLE BIRDIE     80995
#
#            InvoiceDate  UnitPrice  CustomerID         Country     Total
# 540421  12/9/2011 9:15       2.08     16446.0  United Kingdom  168469.6

# %% [markdown]
# ** How many people who live in Spain spend more than average Total ?**

# %%
ecom[(ecom["Country"] == "Spain") & (ecom["Total"] > ecom["Total"].mean())].shape
# Out:
# (728, 9)

# %%
ecom[(ecom["Country"] == "Spain") & (ecom["Total"] > ecom["Total"].mean())].count()
# Out:
# InvoiceNo      728
# StockCode      728
# Description    728
# Quantity       728
# InvoiceDate    728
# UnitPrice      728
# CustomerID     728
# Country        728
# Total          728
# dtype: int64

# %%
len(ecom[(ecom["Country"] == "Spain") & (ecom["Total"] > ecom["Total"].mean())])
# Out:
# 728

# %% [markdown]
# ** Convert datatype of InvoiceDate to datetime and assign it to new column name InvoiceDate2**

# %%
ecom["InvoiceDate2"] = pd.to_datetime(ecom["InvoiceDate"])
ecom["InvoiceDate2"]
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 541904   2011-12-09 12:50:00
# 541905   2011-12-09 12:50:00
# 541906   2011-12-09 12:50:00
# 541907   2011-12-09 12:50:00
# 541908   2011-12-09 12:50:00
# Name: InvoiceDate2, Length: 541909, dtype: datetime64[ns]

# %% [markdown]
# ** Take only date values (year-month-day) from InvoiceDate2 and assign it to a new column named date **

# %%
ecom["date"] = ecom.InvoiceDate2.dt.date
ecom["date"]
# Out:
# 0         2010-12-01
# 1         2010-12-01
# 2         2010-12-01
# 3         2010-12-01
# 4         2010-12-01
#              ...
# 541904    2011-12-09
# 541905    2011-12-09
# 541906    2011-12-09
# 541907    2011-12-09
# 541908    2011-12-09
# Name: date, Length: 541909, dtype: object

# %% [markdown]
# ** drop InvoiceDate2 and InvoiceDate columns permanently **

# %%
ecom.drop(["InvoiceDate2", "InvoiceDate"], axis=1, inplace=True)

# %%
ecom
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#         UnitPrice  CustomerID         Country  Total        date
# 0            2.55     17850.0  United Kingdom  15.30  2010-12-01
# 1            3.39     17850.0  United Kingdom  20.34  2010-12-01
# 2            2.75     17850.0  United Kingdom  22.00  2010-12-01
# 3            3.39     17850.0  United Kingdom  20.34  2010-12-01
# 4            3.39     17850.0  United Kingdom  20.34  2010-12-01
# ...           ...         ...             ...    ...         ...
# 541904       0.85     12680.0          France  10.20  2011-12-09
# 541905       2.10     12680.0          France  12.60  2011-12-09
# 541906       4.15     12680.0          France  16.60  2011-12-09
# 541907       4.15     12680.0          France  16.60  2011-12-09
# 541908       4.95     12680.0          France  14.85  2011-12-09
#
# [541909 rows x 9 columns]

# %% [markdown]
# ** Remove A, B, G and E from first 5 rows of ecom dataframe with a string method **

# %%
ecom.loc[:5, "StockCode"].str.rstrip("ABGE")
# Out:
# 0    85123
# 1    71053
# 2    84406
# 3    84029
# 4    84029
# 5    22752
# Name: StockCode, dtype: object

# %% [markdown]
# ** take only Total and date columns with loc and craete a new df named ecom2 **

# %%
ecom2 = ecom.loc[:, ["Total", "date"]]
ecom2
# Out:
#         Total        date
# 0       15.30  2010-12-01
# 1       20.34  2010-12-01
# 2       22.00  2010-12-01
# 3       20.34  2010-12-01
# 4       20.34  2010-12-01
# ...       ...         ...
# 541904  10.20  2011-12-09
# 541905  12.60  2011-12-09
# 541906  16.60  2011-12-09
# 541907  16.60  2011-12-09
# 541908  14.85  2011-12-09
#
# [541909 rows x 2 columns]

# %% [markdown]
# ** take only InvoiceNo and CustomerID columns with iloc and craete a new df named ecom3 **

# %%
ecom
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#         UnitPrice  CustomerID         Country  Total        date
# 0            2.55     17850.0  United Kingdom  15.30  2010-12-01
# 1            3.39     17850.0  United Kingdom  20.34  2010-12-01
# 2            2.75     17850.0  United Kingdom  22.00  2010-12-01
# 3            3.39     17850.0  United Kingdom  20.34  2010-12-01
# 4            3.39     17850.0  United Kingdom  20.34  2010-12-01
# ...           ...         ...             ...    ...         ...
# 541904       0.85     12680.0          France  10.20  2011-12-09
# 541905       2.10     12680.0          France  12.60  2011-12-09
# 541906       4.15     12680.0          France  16.60  2011-12-09
# 541907       4.15     12680.0          France  16.60  2011-12-09
# 541908       4.95     12680.0          France  14.85  2011-12-09
#
# [541909 rows x 9 columns]

# %%
ecom3 = ecom.iloc[:, [0,5]]
ecom3
# Out:
#        InvoiceNo  CustomerID
# 0         536365     17850.0
# 1         536365     17850.0
# 2         536365     17850.0
# 3         536365     17850.0
# 4         536365     17850.0
# ...          ...         ...
# 541904    581587     12680.0
# 541905    581587     12680.0
# 541906    581587     12680.0
# 541907    581587     12680.0
# 541908    581587     12680.0
#
# [541909 rows x 2 columns]

# %% [markdown]
# ** Combine ecom2 and ecom3 with concat **

# %%
pd.concat([ecom2, ecom3], axis=1)
# Out:
#         Total        date InvoiceNo  CustomerID
# 0       15.30  2010-12-01    536365     17850.0
# 1       20.34  2010-12-01    536365     17850.0
# 2       22.00  2010-12-01    536365     17850.0
# 3       20.34  2010-12-01    536365     17850.0
# 4       20.34  2010-12-01    536365     17850.0
# ...       ...         ...       ...         ...
# 541904  10.20  2011-12-09    581587     12680.0
# 541905  12.60  2011-12-09    581587     12680.0
# 541906  16.60  2011-12-09    581587     12680.0
# 541907  16.60  2011-12-09    581587     12680.0
# 541908  14.85  2011-12-09    581587     12680.0
#
# [541909 rows x 4 columns]

# %% [markdown]
# ** Combine ecom2 and ecom3 with merge **

# %%
ecom2.merge(ecom3, how='right', left_index=True, right_index=True)
# Out:
#         Total        date InvoiceNo  CustomerID
# 0       15.30  2010-12-01    536365     17850.0
# 1       20.34  2010-12-01    536365     17850.0
# 2       22.00  2010-12-01    536365     17850.0
# 3       20.34  2010-12-01    536365     17850.0
# 4       20.34  2010-12-01    536365     17850.0
# ...       ...         ...       ...         ...
# 541904  10.20  2011-12-09    581587     12680.0
# 541905  12.60  2011-12-09    581587     12680.0
# 541906  16.60  2011-12-09    581587     12680.0
# 541907  16.60  2011-12-09    581587     12680.0
# 541908  14.85  2011-12-09    581587     12680.0
#
# [541909 rows x 4 columns]

# %% [markdown]
# ** Combine ecom2 and ecom3 with join **

# %%
ecom2
# Out:
#         Total        date
# 0       15.30  2010-12-01
# 1       20.34  2010-12-01
# 2       22.00  2010-12-01
# 3       20.34  2010-12-01
# 4       20.34  2010-12-01
# ...       ...         ...
# 541904  10.20  2011-12-09
# 541905  12.60  2011-12-09
# 541906  16.60  2011-12-09
# 541907  16.60  2011-12-09
# 541908  14.85  2011-12-09
#
# [541909 rows x 2 columns]

# %%
ecom3
# Out:
#        InvoiceNo  CustomerID
# 0         536365     17850.0
# 1         536365     17850.0
# 2         536365     17850.0
# 3         536365     17850.0
# 4         536365     17850.0
# ...          ...         ...
# 541904    581587     12680.0
# 541905    581587     12680.0
# 541906    581587     12680.0
# 541907    581587     12680.0
# 541908    581587     12680.0
#
# [541909 rows x 2 columns]

# %%
ecom2.join(ecom3)
# Out:
#         Total        date InvoiceNo  CustomerID
# 0       15.30  2010-12-01    536365     17850.0
# 1       20.34  2010-12-01    536365     17850.0
# 2       22.00  2010-12-01    536365     17850.0
# 3       20.34  2010-12-01    536365     17850.0
# 4       20.34  2010-12-01    536365     17850.0
# ...       ...         ...       ...         ...
# 541904  10.20  2011-12-09    581587     12680.0
# 541905  12.60  2011-12-09    581587     12680.0
# 541906  16.60  2011-12-09    581587     12680.0
# 541907  16.60  2011-12-09    581587     12680.0
# 541908  14.85  2011-12-09    581587     12680.0
#
# [541909 rows x 4 columns]

# %% [markdown]
# # Congrats!
