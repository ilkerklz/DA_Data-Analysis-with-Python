# %% [markdown]
# # **Data Analysis with Python - 7  (05 May 22)**

# %% [markdown]
# ## **Pre-Class**

# %% [markdown]
# ### **Useful Methods**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.DataFrame({'col1':[1,2,3,4], 'col2':[444, 555, 666, 444]})
df
# Out:
#    col1  col2
# 0     1   444
# 1     2   555
# 2     3   666
# 3     4   444

# %% [markdown]
# `apply()` : Apply a function along an axis of the DataFrame. Series in given axis are passed to the function.

# %% [markdown]
# Row or Column Wise Function Application: `apply()`

# %%
df.apply(np.mean)
# Out:
# col1      2.50
# col2    527.25
# dtype: float64

# %%
df.apply(np.std)
# Out:
# col1     1.118034
# col2    92.036338
# dtype: float64

# %%
type(df.apply(np.mean))
# Out:
# pandas.core.series.Series

# %% [markdown]
# Element wise Function Application: `applymap()`

# %%
df.applymap(lambda x: x*5)
# Out:
#    col1  col2
# 0     5  2220
# 1    10  2775
# 2    15  3330
# 3    20  2220

# %%
df.applymap(np.mean) # doesn't make sense, it only does element-wise operation
# Out:
#    col1   col2
# 0   1.0  444.0
# 1   2.0  555.0
# 2   3.0  666.0
# 3   4.0  444.0

# %%
df.apply(lambda x: x+2)
# Out:
#    col1  col2
# 0     3   446
# 1     4   557
# 2     5   668
# 3     6   446

# %%
df.applymap(lambda x: x+2)
# Out:
#    col1  col2
# 0     3   446
# 1     4   557
# 2     5   668
# 3     6   446

# %% [markdown]
# Function application on Series : `map()`

# %%
df.col1.map({3:'A'})
# Out:
# 0    NaN
# 1    NaN
# 2      A
# 3    NaN
# Name: col1, dtype: object

# %%
df['col2'].map({555:"DDD"})
# Out:
# 0    NaN
# 1    DDD
# 2    NaN
# 3    NaN
# Name: col2, dtype: object

# %%
df
# Out:
#    col1  col2
# 0     1   444
# 1     2   555
# 2     3   666
# 3     4   444

# %%
df1 = pd.DataFrame({"Company": ["FB", "GOOG", "MSFT", "GOOG", "MSFT", "FB"],
                    "Person": ["Edward", "Charlie", "Amy", "Vanessa", "Carl", "Sarah"],
                    "Sales": [200, 120, 340, 124, 243, 350]})

df1
# Out:
#   Company   Person  Sales
# 0      FB   Edward    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    GOOG  Vanessa    124
# 4    MSFT     Carl    243
# 5      FB    Sarah    350

# %% [markdown]
# `unique()` : Compute array of unique values in a Series, returned in the order observed

# %%
df1.Company.unique()
# Out:
# array(['FB', 'GOOG', 'MSFT'], dtype=object)

# %%
df1.loc[:, "Company"].unique()
# Out:
# array(['FB', 'GOOG', 'MSFT'], dtype=object)

# %%
df1.iloc[:, 0].unique()
# Out:
# array(['FB', 'GOOG', 'MSFT'], dtype=object)

# %%
df1["Company"]
# Out:
# 0      FB
# 1    GOOG
# 2    MSFT
# 3    GOOG
# 4    MSFT
# 5      FB
# Name: Company, dtype: object

# %% [markdown]
# `nunique()`: gives the number of unique values

# %%
df1.Person.nunique()
# Out:
# 6

# %%
df1.Company.nunique()
# Out:
# 3

# %% [markdown]
# `value_counts()` : Returns a Series containing unique values as its index and frequencies as its values, ordered count in descending order

# %%
df1.Company.value_counts()
# Out:
# FB      2
# GOOG    2
# MSFT    2
# Name: Company, dtype: int64

# %% [markdown]
# `sort_values()` : Sort by the values. Sort a Series in ascending or descending order by some criterion.

# %%
df1.Company.sort_values()
# Out:
# 0      FB
# 5      FB
# 1    GOOG
# 3    GOOG
# 2    MSFT
# 4    MSFT
# Name: Company, dtype: object

# %%
training_df = pd.read_csv('http://bit.ly/kaggletrain')

training_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Create a dummy variable with `map()`
#
# `map()` is a series method

# %%
training_df["Sex_num"] = training_df.Sex.map({'female':0, 'male':1})

# %%
# let's compare
training_df.loc[0:4, ["Sex", "Sex_num"]]
# Out:
#       Sex  Sex_num
# 0    male        1
# 1  female        0
# 2  female        0
# 3  female        0
# 4    male        1

# %% [markdown]
# `apply()` is both a **series** and a **dataframe** method

# %% [markdown]
# apply() as a Series method

# %%
# let's caluculate the lenght of values in 'Name' column
training_df["Name_length"] = training_df.Name.apply(len) # just passed the finction name without parens

# %%
# compare
training_df.loc[0:4, ["Name", "Name_length"]]
# Out:
#                                                 Name  Name_length
# 0                            Braund, Mr. Owen Harris           23
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...           51
# 2                             Heikkinen, Miss. Laina           22
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)           44
# 4                           Allen, Mr. William Henry           24

# %%
# let's round "Fare" column values with 'numpy ceil' function
import numpy as np
training_df["Fare_ceil"] = training_df.Fare.apply(np.ceil)

# %%
training_df.loc[0:4, ["Fare", "Fare_ceil"]]
# Out:
#       Fare  Fare_ceil
# 0   7.2500        8.0
# 1  71.2833       72.0
# 2   7.9250        8.0
# 3  53.1000       54.0
# 4   8.0500        9.0

# %%
# let's just return last names
training_df.Name.str.split(',').head()
# Out:
# 0                           [Braund,  Mr. Owen Harris]
# 1    [Cumings,  Mrs. John Bradley (Florence Briggs ...
# 2                            [Heikkinen,  Miss. Laina]
# 3      [Futrelle,  Mrs. Jacques Heath (Lily May Peel)]
# 4                          [Allen,  Mr. William Henry]
# Name: Name, dtype: object

# %%
def get_element(my_list, position):
    return my_list[position]

# %%
training_df.Name.str.split(',').apply(get_element, position=0).head()
# Out:
# 0       Braund
# 1      Cumings
# 2    Heikkinen
# 3     Futrelle
# 4        Allen
# Name: Name, dtype: object

# %%
training_df.Name.str.split(',').apply(lambda x: x[0]).head()
# Out:
# 0       Braund
# 1      Cumings
# 2    Heikkinen
# 3     Futrelle
# 4        Allen
# Name: Name, dtype: object

# %% [markdown]
# apply() as a DataFrame method, it applies a function along either axis of a DataFrame

# %%
drinks = pd.read_csv('http://bit.ly/drinksbycountry')
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.loc[:, 'beer_servings':'wine_servings']
# Out:
#      beer_servings  spirit_servings  wine_servings
# 0                0                0              0
# 1               89              132             54
# 2               25                0             14
# 3              245              138            312
# 4              217               57             45
# ..             ...              ...            ...
# 188            333              100              3
# 189            111                2              1
# 190              6                0              0
# 191             32               19              4
# 192             64               18              4
#
# [193 rows x 3 columns]

# %%
type(drinks.loc[:, 'beer_servings':'wine_servings'])
# Out:
# pandas.core.frame.DataFrame

# %%
# apply method as DataFrame
drinks.loc[:, 'beer_servings':'wine_servings'].apply(max, axis=0)
# Out:
# beer_servings      376
# spirit_servings    438
# wine_servings      370
# dtype: int64

# %%
drinks.loc[:, 'beer_servings':'wine_servings'].apply(np.argmax, axis=1)
# Out:
# 0      0
# 1      1
# 2      0
# 3      2
# 4      0
#       ..
# 188    0
# 189    0
# 190    0
# 191    0
# 192    0
# Length: 193, dtype: int64

# %%
type(drinks.loc[:, 'beer_servings':'wine_servings'].apply(max, axis=0))
# Out:
# pandas.core.series.Series

# %% [markdown]
# `applymap()` is a **dataframe** method, it's element-wise

# %%
# let's change all values from int to float
drinks.loc[:, 'beer_servings':'wine_servings'].applymap(float)
# Out:
#      beer_servings  spirit_servings  wine_servings
# 0              0.0              0.0            0.0
# 1             89.0            132.0           54.0
# 2             25.0              0.0           14.0
# 3            245.0            138.0          312.0
# 4            217.0             57.0           45.0
# ..             ...              ...            ...
# 188          333.0            100.0            3.0
# 189          111.0              2.0            1.0
# 190            6.0              0.0            0.0
# 191           32.0             19.0            4.0
# 192           64.0             18.0            4.0
#
# [193 rows x 3 columns]

# %% [markdown]
# ### **Missing Data Handling**

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# `dropna()` method drops the missing values along with the axis argument

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic.age.dropna().isnull().sum()
# Out:
# 0

# %% [markdown]
# `fillna()` method can “fill in” NA values with non-null data
#
# method : {'backfill', 'bfill', 'pad', 'ffill', None}, default None
#     Method to use for filling holes in reindexed Series
#
# pad / ffill: propagate last valid observation forward to next valid
#
# backfill / bfill: use next valid observation to fill gap.

# %%
titanic.age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
titanic.age.fillna(method="ffill")
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    19.0
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %% [markdown]
# `replace()` method similar to fillna “fill in” NA values with non-null values.

# %%
titanic.age.tail()
# Out:
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, dtype: float64

# %%
titanic.age.tail().replace([np.nan], method='bfill')
# Out:
# 886    27.0
# 887    19.0
# 888    26.0
# 889    26.0
# 890    32.0
# Name: age, dtype: float64

# %% [markdown]
# `interpolate()` method uses various interpolation technique to fill the missing values.

# %%
titanic.age.tail(20)
# Out:
# 871    47.0
# 872    33.0
# 873    47.0
# 874    28.0
# 875    15.0
# 876    20.0
# 877    19.0
# 878     NaN
# 879    56.0
# 880    25.0
# 881    33.0
# 882    22.0
# 883    28.0
# 884    25.0
# 885    39.0
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, dtype: float64

# %%
titanic.age.tail(20).interpolate()
# Out:
# 871    47.0
# 872    33.0
# 873    47.0
# 874    28.0
# 875    15.0
# 876    20.0
# 877    19.0
# 878    37.5
# 879    56.0
# 880    25.0
# 881    33.0
# 882    22.0
# 883    28.0
# 884    25.0
# 885    39.0
# 886    27.0
# 887    19.0
# 888    22.5
# 889    26.0
# 890    32.0
# Name: age, dtype: float64

# %%
banglore_df = pd.read_csv('Bengaluru_House_Data.csv')
banglore_df.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
banglore_df.shape
# Out:
# (13320, 9)

# %%
banglore_df.isnull()
# Out:
#        area_type  availability  location   size  society  total_sqft   bath  \
# 0          False         False     False  False    False       False  False
# 1          False         False     False  False    False       False  False
# 2          False         False     False  False     True       False  False
# 3          False         False     False  False    False       False  False
# 4          False         False     False  False     True       False  False
# ...          ...           ...       ...    ...      ...         ...    ...
# 13315      False         False     False  False    False       False  False
# 13316      False         False     False  False     True       False  False
# 13317      False         False     False  False    False       False  False
# 13318      False         False     False  False    False       False  False
# 13319      False         False     False  False     True       False  False
#
#        balcony  price
# 0        False  False
# ...

# %%
banglore_df.isnull().sum() # number of null values by columns
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
banglore_df.isnull().sum().sum() #total number of all null values in dataframe
# Out:
# 6201

# %%
banglore_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %% [markdown]
# ### Filling Null Values

# %%
df2 = banglore_df.fillna(value=0) # replace null values with zero
df2
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df2.isnull().sum().sum()
# Out:
# 0

# %%
banglore_df.isnull().sum().sum() # original dataframe's total NaN
# Out:
# 6201

# %%
df3 = banglore_df.fillna(value=5) # replace null values with five
df3
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
# Filling null values with the previous value "row-wise"

df4 = banglore_df.fillna(method="pad")
df4
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df4.isnull().sum()
# Out:
# area_type       0
# availability    0
# location        0
# size            0
# society         0
# total_sqft      0
# bath            0
# balcony         0
# price           0
# dtype: int64

# %%
banglore_df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
# Filling null values with the next value  "row-wise"

df5 = banglore_df.fillna(method="bfill")
df5
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
# Filling null values with the previous value  "column-wise"
df6 = banglore_df.fillna(method='pad', axis=1)
df6
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft bath balcony  price
# 0          2 BHK  Coomee        1056  2.0     1.0  39.07
# ...

# %%
# Filling null values with the next value  "column-wise"
df7 = banglore_df.fillna(method='bfill', axis=1)
df7
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft bath balcony  price
# 0          2 BHK  Coomee        1056  2.0     1.0  39.07
# ...

# %%
banglore_df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
# Filling Different Values in Null in different columns

df8 = banglore_df.fillna({'society':'abcd', 'balcony':'defg'})
df8
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath balcony   price
# 0          2 BHK  Coomee        1056   2.0     1.0   39.07
# ...

# %% [markdown]
# ## **In-Class (05 May 22)**
